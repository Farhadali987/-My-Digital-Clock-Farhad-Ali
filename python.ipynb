# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhadali987/-My-Digital-Clock-Farhad-Ali/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# what is python?

# %% [markdown]
# 1.   Python is simple and easy
# 2.   free and open source
# 3.   High level language
# 4.   developed by guido van rossum

# %% [markdown]
# Our first program

# %%
print("hello world")
# Out:
# hello world

# %%
print("My name is farhad")

# %% [markdown]
# Python Character set
#
# *   Letters_A to Z, a to b
# *   Digits_ 0 to 9
# *   Special symobols -+-* etc.
# *   WitheSpaces_Blank space,Tap carriage retun,newline,formfeed.
# *   other characters-python can process all ASCLL an unicode characters as part of data or literals.

# %%
print("Farhad is my  name ")
print(32)
print(35)
print(23+35)
# Out:
# Farhad is my  name
# 32
# 35
# 58

# %% [markdown]
# # Variables

# %% [markdown]
# A Variables is a name given to a memory location in a program.

# %%
name = "farhad"
age = 21
print(name)
print(age)
# Out:
# farhad
# 21

# %%
name = "farhad"
age = 21
print("My name is:",name)
print("My age is:",age)
# Out:
# My name is: farhad
# My age is: 21

# %%
name = "farhad"
age = 21
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# # Rules for identifiers
# 1.  Identifiers can be combination of UpperCase and Lowercase letter,digits or an underscore(_).son myvariable,variable_for_Print all are valid python identifiers.
#
# 2. An identifiers can not start with digit.so while vaiable1 is valid, 1vaiable is not valid.
#
# 3. We can't use special symbols like !,#,@,%,$ etc in our identifies.
#
# 4. Identifiers can be of any length.

# %% [markdown]
# ### Data Types
#
#
# 1.   Integers
# 2.   String
# 3.   Float
# 4.   Boolean
# 5.   None

# %% [markdown]
# # Intergers
# Number 1 to 9 and -1 to -9

# %%
num1 = 54
num2 = 45
num3= -43
print(type(num1))
print(type(num2))
print(type(num3))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
num = -34
num1 = 455
num3 = -34
print(type(num))
print(type(num1))
print(type(num3))

# %% [markdown]
# # String

# %%
name1 = "Sk"
Name2 = 'sk'
name3 = """sk"""

print(type(name1))
print(type(Name2))
print(type(name3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# # **Float**

# %%
price1 = 99.5
price2 = 79.99
price3 = 50.85

print(type(price1))
print(type(price2))
print(type(price3))

# %% [markdown]
# # **Boolean**

# %%
Isyoustudent = True
Isyoumarij = False
print(type(Isyoumarij),Isyoumarij,Isyoustudent)

is_student = True
is_name = False
print(type(is_name),is_name,is_student)

# %% [markdown]
# # **None**

# %%
a = None
print(type(a))

# %% [markdown]
# # **Print Sum**

# %%
a = 290
b = 210
print(a+b)
# Out:
# 500

# %%
num = 12
# num2 = 34
num1 = 23
print(num+num1-num3)
# Out:
# 78

# %% [markdown]
# # **Comments In Python **

# %%
# Single line comments

# """
# multi line
# comments
# """

print("hi")

print("hi")

# %% [markdown]
# # Types Operators
#
# An  Operators is a symbol that performs a certain operation between operands.
#
# 1.Arithmetic  Operators(+,-,,/,%,*)
#
# 2. Relational| comparison Operators(==,!=,>,<,>=,<=)
#
# 3. Assignment  Operators(=,+=,-=,=,/=,%=,*=)
#
# 4. Logical Operators(not , and, or)

# %% [markdown]
# # Arithmetic Operators

# %%
a = 5
b = 2
sum = a+b
print(sum)
# Out:
# 7

# %%
a = 5
b = 2
print(a+b)

# %%
a = 5
b = 2

sum = a*b
print(sum)

# %%
a = 5
b = 2
print(a*b)

# %%
a = 5
b = 2

sum = a/b
print(sum)

# %%
a = 5
b = 2
print(a/b)

# %%
a = 5
b = 2

sum = a%b
print(sum)

# %%
a = 5
b = 2
print(a%b)

# %%
a = 5
b = 2

sum = a**b
print(sum)

# %%
a = 5
b = 2
print(a**b)

# %% [markdown]
# # Relational| comparison Operators

# %%
a = 50
b = 20
print(a==b)

# %%
a = 50
b = 50
print(a==b)

# %%
a = 50
b = 20
print(a!=b)

# %%
a = 50
b = 50
print(a!=b)

# %%
a = 50
b = 20
print(a>=b)

a = 50
b = 200
print(a>=b)
# Out:
# True
# False

# %%
a = 50
b = 20
print(a<=b)

# %%
a = 50
b = 20
print(a>b)
print(b>a)

# %%
a = 50
b = 20
print(a<b)
print(b<a)

# %% [markdown]
# # Assignment  Operators

# %%
num = 10
num = num + 10 # 10 + 10 = 20
print(num)
# Out:
# 20

# %%
num = 10
num += 10
print(num)

# %%
num = 10
num -= 10
print(num)

# %%
num = 10
num *= 10
print(num)

# %%
num = 10
num /= 10
print(num)

# %%
num = 10
num %= 10
print(num)

# %%
num = 5
num %= 2
print(num)

# %% [markdown]
# # Logical Operators

# %%
print(not False)

print(not True)

# %%
a = 50
b = 30
print(not(a>b))

# %%
val1 = True
val2 = True
print(val1 and val2)

# %%
val1 = True
val2 = False
print(val1 and val2)

# %%
val1 = True
val2 = True
print(val1 or val2)

# %%
val1 = True
val2 = False
print(val1 or val2)

# %% [markdown]
# # type conversion

# %%
a,b= 1,2.0
sum = a+b
print(sum)
# Out:
# 3.0

# %%
# error

a,b= 1 , "2"
sum = a+b
print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-187f05f0fcd7> in <cell line: 0>()
#       2
#       3 a,b= 1 , "2"
# ----> 4 sum = a+b
#       5 print(sum)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 2
b = 4.25
sum = a + b
print(type(sum),'Ans',sum)
# Out:
# <class 'float'> Ans 6.25

# %%
a = "2"
b = 4.28

print(a+b)  ## error

# %% [markdown]
# # type casting

# %%
a,b = 1 , "2"
c = int(b)
print(a+c)

# %%
a = int("5")
b = 4.27
print(type(a))
print(a+b)
